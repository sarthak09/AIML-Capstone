# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 13567 (delta 1), reused 1 (delta 0), pack-reused 13559
# Receiving objects: 100% (13567/13567), 12.20 MiB | 25.29 MiB/s, done.
# Resolving deltas: 100% (9256/9256), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /darknet

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# make darknet (build)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ...

# %%
# get yolov3 pretrained coco dataset weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-05-26 18:11:44--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   134KB/s    in 14m 7s
#
# 2020-05-26 18:25:52 (286 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()


def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

 
def download(path):
  from google.colab import files
  files.download(path)

# %%
# run darknet detection
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 610, cudnn_half = 0, GPU: Tesla P4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
imShow('predictions.jpg')

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg
imShow('predictions.jpg')
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 610, cudnn_half = 0, GPU: Tesla P4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir('/content')

# %%
# !ls
# Out:
# darknet  gdrive  sample_data

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s ../gdrive/My\ Drive/ /mydrive

# %%
# !ls
# Out:
# 3rdparty   CMakeLists.txt	   include		  results
# backup	   darknet		   json_mjpeg_streams.sh  scripts
# bad.list   DarknetConfig.cmake.in  LICENSE		  src
# build	   darknet.py		   Makefile		  video_v2.sh
# build.ps1  darknet_video.py	   net_cam_v3.sh	  video_yolov3.sh
# build.sh   data			   obj			  yolov3.weights
# cfg	   image_yolov2.sh	   predictions.jpg
# cmake	   image_yolov3.sh	   README.md

# %%
# !ls
# Out:
# darknet  gdrive  sample_data

# %%
# !ls gdrive/'My Drive'/capstone_yolo
# Out:
# backup		   my-yolo.ipynb  obj.names  yolov3_custom.cfg
# generate_train.py  obj.data	  obj.zip

# %%
# !cp gdrive/'My Drive'/capstone_yolo/obj.zip /content

# %%
# !unzip obj.zip -d darknet/data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: darknet/data/obj/a011c70e-6fda-4056-b364-8bfa67a878d0.txt
#   inflating: darknet/data/obj/a01dc83f-bd19-454b-a317-007a2730852a.jpg
#   inflating: darknet/data/obj/a01dc83f-bd19-454b-a317-007a2730852a.txt
#   inflating: darknet/data/obj/a024d155-a276-4395-826b-193fcf6a5b9c.jpg
#   inflating: darknet/data/obj/a024d155-a276-4395-826b-193fcf6a5b9c.txt
#   inflating: darknet/data/obj/a02a2b40-a352-4e80-8390-d44e1264bcb7.jpg
#   inflating: darknet/data/obj/a02a2b40-a352-4e80-8390-d44e1264bcb7.txt
#   inflating: darknet/data/obj/a02c7ae4-7571-4ae8-ae35-5e4121ebd250.jpg
#   inflating: darknet/data/obj/a02c7ae4-7571-4ae8-ae35-5e4121ebd250.txt
#   inflating: darknet/data/obj/a0367348-011f-4ec9-9efa-144fd325ba5f.jpg
#   inflating: darknet/data/obj/a0367348-011f-4ec9-9efa-144fd325ba5f.txt
#   inflating: darknet/data/obj/a03a2aab-7039-4743-9dab-3870899b1f35.jpg
# ...

# %%
# download cfg to google drive and change its name
# !cp /content/darknet/cfg/yolov3.cfg /content/gdrive/'My Drive'/capstone_yolo/yolov3_custom.cfg

# %%
# !ls gdrive/My\ Drive/capstone_yolo
# Out:
# backup		   my-yolo.ipynb  obj.names  yolov3_custom.cfg
# generate_train.py  obj.data	  obj.zip

# %%
# upload the custom .cfg back to cloud VM from Google Drive
# !cp /content/gdrive/'My Drive'/capstone_yolo/yolov3_custom.cfg  darknet/cfg

# %%
# !ls darknet/data
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   openimages.names
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  person.jpg
# coco.names  goal.txt	 labels			   scream.jpg
# dog.jpg     horses.jpg	 obj			   voc.names

# %%
# !cp gdrive/'My Drive'/capstone_yolo/obj.names darknet/data
# !cp gdrive/'My Drive'/capstone_yolo/obj.data  darknet/data
# !ls
# Out:
# darknet  gdrive  obj.zip  sample_data

# %%
# !ls
# Out:
# darknet  gdrive  obj.zip  sample_data

# %%
# !cp gdrive/My\ Drive/capstone_yolo/generate_train.py darknet/data

# %%
#NOTE change working diretory to darknet
import os
os.chdir("darknet")
# !ls
# Out:
# 3rdparty   CMakeLists.txt	   include		  results
# backup	   darknet		   json_mjpeg_streams.sh  scripts
# bad.list   DarknetConfig.cmake.in  LICENSE		  src
# build	   darknet.py		   Makefile		  video_v2.sh
# build.ps1  darknet_video.py	   net_cam_v3.sh	  video_yolov3.sh
# build.sh   data			   obj			  yolov3.weights
# cfg	   image_yolov2.sh	   predictions.jpg
# cmake	   image_yolov3.sh	   README.md

# %%
# !python data/generate_train.py

# %%
# verify train.txt can be seen in our darknet/data folder
# !ls data/
# Out:
# 9k.tree     generate_train.py	  imagenet.shortnames.list  openimages.names
# coco9k.map  giraffe.jpg		  labels		    person.jpg
# coco.names  goal.txt		  obj			    scream.jpg
# dog.jpg     horses.jpg		  obj.data		    train.txt
# eagle.jpg   imagenet.labels.list  obj.names		    voc.names

# %%
# upload pretrained convolutional layer weights
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2020-05-26 18:29:51--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   224KB/s    in 11m 30s
#
# 2020-05-26 18:41:22 (230 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !ls data
# Out:
# 9k.tree     generate_train.py	  imagenet.shortnames.list  openimages.names
# coco9k.map  giraffe.jpg		  labels		    person.jpg
# coco.names  goal.txt		  obj			    scream.jpg
# dog.jpg     horses.jpg		  obj.data		    train.txt
# eagle.jpg   imagenet.labels.list  obj.names		    voc.names

# %%
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 94 Avg (IOU: 0.737810, GIOU: 0.719911), Class: 0.996494, Obj: 0.167889, No Obj: 0.000083, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.177197, iou_loss = 0.035325, total_loss = 0.212522
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 106 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000001, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
#
#  1903: 0.693109, 0.677311 avg loss, 0.000010 rate, 11.665249 seconds, 121792 images, 0.358103 hours left
# Loaded: 0.000053 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 82 Avg (IOU: 0.726385, GIOU: 0.725479), Class: 0.999453, Obj: 0.078123, No Obj: 0.001037, .5R: 0.833333, .75R: 0.666667, count: 6, class_loss = 1.439172, iou_loss = 0.733731, total_loss = 2.172903
# ...

# %%
 # !ls
# Out:
# 3rdparty		 darknet		 Makefile
# backup			 darknet53.conv.74	 net_cam_v3.sh
# bad.list		 DarknetConfig.cmake.in  obj
# build			 darknet.py		 predictions.jpg
# build.ps1		 darknet_video.py	 README.md
# build.sh		 data			 results
# cfg			 image_yolov2.sh	 scripts
# chart.png		 image_yolov3.sh	 src
# chart_yolov3_custom.png  include		 video_v2.sh
# cmake			 json_mjpeg_streams.sh	 video_yolov3.sh
# CMakeLists.txt		 LICENSE		 yolov3.weights

# %%
# !cp ../yolov3_custom_1000.weights ../gdrive/My\ Drive/capstone_yolo/backup
# !cp ../yolov3_custom_2000.weights ../gdrive/My\ Drive/capstone_yolo/backup
# !cp ../yolov3_custom_final.weights ../gdrive/My\ Drive/capstone_yolo/backup
# !cp ../yolov3_custom_last.weights ../gdrive/My\ Drive/capstone_yolo/backup

# %% [markdown]
# A chart to show how our model did throughout the training process. It is average loss vs. iterations.

# %%
imShow('chart.png')

# %%
#!./darknet detector train data/obj.data cfg/yolov3_custom.cfg /mydrive/yolov3/backup/yolov3_custom_last.weights -dont_show
